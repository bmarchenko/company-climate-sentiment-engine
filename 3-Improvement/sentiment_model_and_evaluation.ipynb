# %%
import pandas as pd
import re
import spacy
from collections import Counter
import unicodedata
from bs4 import BeautifulSoup
from boilerpipe.extract import Extractor
from sklearn.metrics import classification_report
from nltk.corpus import stopwords
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from nltk.corpus import stopwords
stopwords = set(stopwords.words())
INPUT_FILE = "../1-Data/3-annotation/output.csv"
# INPUT_FILE = "filtered_by_company_confidence.csv"

nlp = spacy.load('en_core_web_sm')
alternative_company_names = {"AMD (Advanced Micro Devices)": "AMD",
                    'Royal Dutch Shell PLC': "Shell",
                    "Samsung Electronics Co., Ltd.": "Samsung",
                    "Goodyear Tire & Rubber Co": "Goodyear",
                    "Sumitomo Rubber Industries": "Sumitomo",
                    "Exxon Mobil Corp.": "ExxonMobil",
                    "General Motors Corp.": "GM",
                    "Ford Motor Co.": "Ford",
                    "Toyota Motor Corp.": "Toyota",
                    "Petro China": "PetroChina",
                    'Volkswagen AG': "VW"}

def clean_text(html):
    soup = BeautifulSoup(html, "html.parser") # create a new bs4 object from the html data loaded
    for script in soup(["script", "style"]): # remove all javascript and stylesheet code
        script.extract()
    texts = soup.findAll(text=True)
#     import ipdb; ipdb.set_trace()
#     print(len(texts))
    text = ". ".join(t.strip() for t in texts)
    text = unicodedata.normalize("NFKD", text)
    return text

# %% [markdown]
# Clean text from html tags

# %%
df = pd.read_csv(INPUT_FILE)

# %%
len(df)
# Out:
# 410

# %%
df = pd.read_csv(INPUT_FILE)
df['text'] = df.apply(lambda row: "{} {}".format(row['title'], clean_text(str(row['content']))), axis=1)
df.drop(df[df.text.str.len() < 150].index, inplace=True)

# %%
len(df)
# Out:
# 393

# %%
# COMPANY_NAMES_STOP_WORDS = "PLC|Corp"
with open("company-suffix.txt", "r") as fl:
    text = [i for i in fl.read().split('\n') if not i.startswith('//')]
    COMPANY_NAMES_STOP_WORDS = "(" + "$)|(".join(text) + "$)"

# %%
def get_company_names(company):
    company_names = [re.sub(COMPANY_NAMES_STOP_WORDS, '', company, flags=re.IGNORECASE).strip().lower()]
    if company in alternative_company_names:
        company_names.append(alternative_company_names[company].lower())
    #Company is often mentioned by part of it's name. e.g. "Royal Dutch Shell" -> "Shell"
#     company_names = set([company] + [i for i in company.split() if len(i)>2])
    return company_names

# %%
# pd.options.display.max_colwidth = 10000
# row = df.loc[df['url'] == 'http://www.sustainablebrands.com/solutionproviders/basf']
# row
len(df)
# Out:
# 393

# %%
target_names=('Strongly Negative', 'Negative', 'Neutral', 'Positive', 'Strongly Positive')
cleaned_df = df[(df['company_confidence'] != 0) & (df['climate_confidence'] != 0)]
cleaned_df = cleaned_df.dropna(subset =["sentiment"])

# cleaned_df.dropna(subset=['sentiment'], how='all', inplace = True)
simple_dc = {"Strongly Negative": '0', "Negative": '0', "Neutral": '2', "Positive": '1', "Strongly Positive": '1'}
cleaned_df['simple_sentiment'] = cleaned_df.apply(lambda row: simple_dc[row['sentiment']] ,axis=1)
print("Total: {} texts".format(len(cleaned_df)))
print("Sentiment counts:")
print(cleaned_df['sentiment'].value_counts(normalize=True))
print("Simple Sentiment counts:")
print(cleaned_df['simple_sentiment'].value_counts(normalize=True))
# Out:
# Total: 242 texts
# Sentiment counts:
# Positive             0.442149
# Negative             0.260331
# Neutral              0.148760
# Strongly Positive    0.082645
# Strongly Negative    0.066116
# Name: sentiment, dtype: float64
# Simple Sentiment counts:
# 1    0.524793
# 0    0.326446
# 2    0.148760
# Name: simple_sentiment, dtype: float64

# %% [markdown]
# # BoW Again
#
# taken from https://gist.github.com/bbengfort/044682e76def583a12e6c09209c664a1

# %%
import os
import time
import string
import pickle

from operator import itemgetter

from nltk.corpus import stopwords as sw
from nltk.corpus import wordnet as wn
from nltk import wordpunct_tokenize
from nltk import WordNetLemmatizer
from nltk import sent_tokenize
from nltk import pos_tag

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import SGDClassifier
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import classification_report as clsr
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cross_validation import train_test_split as tts


def timeit(func):
    """
    Simple timing decorator
    """
    def wrapper(*args, **kwargs):
        start  = time.time()
        result = func(*args, **kwargs)
        delta  = time.time() - start
        return result, delta
    return wrapper


def identity(arg):
    """
    Simple identity function works as a passthrough.
    """
    return arg


class NLTKPreprocessor(BaseEstimator, TransformerMixin):
    """
    Transforms input data by using NLTK tokenization, lemmatization, and
    other normalization and filtering techniques.
    """

    def __init__(self, stopwords=None, punct=None, lower=True, strip=True):
        """
        Instantiates the preprocessor, which make load corpora, models, or do
        other time-intenstive NLTK data loading.
        """
        self.lower      = lower
        self.strip      = strip
        self.stopwords  = set(stopwords) if stopwords else set(sw.words('english'))
        self.punct      = set(punct) if punct else set(string.punctuation)
        self.punct.add("“")
        self.lemmatizer = WordNetLemmatizer()

    def fit(self, X, y=None):
        """
        Fit simply returns self, no other information is needed.
        """
        return self

    def inverse_transform(self, X):
        """
        No inverse transformation
        """
        return X

    def transform(self, X):
        """
        Actually runs the preprocessing on each document.
        """
        return [
            list(self.tokenize(doc)) for doc in X
        ]

    def tokenize(self, document):
        """
        Returns a normalized, lemmatized list of tokens from a document by
        applying segmentation (breaking into sentences), then word/punctuation
        tokenization, and finally part of speech tagging. It uses the part of
        speech tags to look up the lemma in WordNet, and returns the lowercase
        version of all the words, removing stopwords and punctuation.
        """
        # Break the document into sentences
        for sent in sent_tokenize(document):
            # Break the sentence into part of speech tagged tokens
            for token, tag in pos_tag(wordpunct_tokenize(sent)):
                # Apply preprocessing to the token
                token = token.lower() if self.lower else token
                token = token.strip() if self.strip else token
                token = token.strip('_') if self.strip else token
                token = token.strip('*') if self.strip else token

                # If punctuation or stopword, ignore token and continue
                if token in self.stopwords or all(char in self.punct for char in token):
                    continue
                if tag == "NNP":
                    continue
                # Lemmatize the token and yield
                lemma = self.lemmatize(token, tag)
                yield lemma

    def lemmatize(self, token, tag):
        """
        Converts the Penn Treebank tag to a WordNet POS tag, then uses that
        tag to perform much more accurate WordNet lemmatization.
        """
        tag = {
            'N': wn.NOUN,
            'V': wn.VERB,
            'R': wn.ADV,
            'J': wn.ADJ
        }.get(tag[0], wn.NOUN)

        return self.lemmatizer.lemmatize(token, tag)



@timeit
def build_and_evaluate(X, y, classifier=SGDClassifier, outpath=None, verbose=True):
    """
    Builds a classifer for the given list of documents and targets in two
    stages: the first does a train/test split and prints a classifier report,
    the second rebuilds the model on the entire corpus and returns it for
    operationalization.
    X: a list or iterable of raw strings, each representing a document.
    y: a list or iterable of labels, which will be label encoded.
    Can specify the classifier to build with: if a class is specified then
    this will build the model with the Scikit-Learn defaults, if an instance
    is given, then it will be used directly in the build pipeline.
    If outpath is given, this function will write the model as a pickle.
    If verbose, this function will print out information to the command line.
    """

    @timeit
    def build(classifier, X, y=None):
        """
        Inner build function that builds a single model.
        """
        if isinstance(classifier, type):
            classifier = classifier(loss='log')

        model = Pipeline([
            ('preprocessor', NLTKPreprocessor()),
            ('vectorizer', TfidfVectorizer(tokenizer=identity, preprocessor=None, lowercase=False)),
            ('classifier', classifier),
        ])

        model.fit(X, y)
        return model

    # Label encode the targets
    labels = LabelEncoder()
    y = labels.fit_transform(y)

    # Begin evaluation
    if verbose: print("Building for evaluation")
    X_train, X_test, y_train, y_test = tts(X, y, test_size=0.2)
    model, secs = build(classifier, X_train, y_train)

    if verbose: print("Evaluation model fit in {:0.3f} seconds".format(secs))
    if verbose: print("Classification Report:\n")

    y_pred = model.predict(X_test)
    print(clsr(y_test, y_pred, target_names=labels.classes_))

    if verbose: print("Building complete model and saving ...")
    model, secs = build(classifier, X, y)
    model.labels_ = labels

    if verbose: print("Complete model fit in {:0.3f} seconds".format(secs))

    if outpath:
        with open(outpath, 'wb') as f:
            pickle.dump(model, f)

        print("Model written out to {}".format(outpath))

    return model


def show_most_informative_features(model, text=None, n=20):
    """
    Accepts a Pipeline with a classifer and a TfidfVectorizer and computes
    the n most informative features of the model. If text is given, then will
    compute the most informative features for classifying that text.
    Note that this function will only work on linear models with coefs_
    """
    # Extract the vectorizer and the classifier from the pipeline
    vectorizer = model.named_steps['vectorizer']
    classifier = model.named_steps['classifier']

    # Check to make sure that we can perform this computation
    if not hasattr(classifier, 'coef_'):
        raise TypeError(
            "Cannot compute most informative features on {} model.".format(
                classifier.__class__.__name__
            )
        )

    if text is not None:
        # Compute the coefficients for the text
        tvec = model.transform([text]).toarray()
    else:
        # Otherwise simply use the coefficients
        tvec = classifier.coef_

    # Zip the feature names with the coefs and sort
    coefs = sorted(
        zip(tvec[0], vectorizer.get_feature_names()),
        key=itemgetter(0), reverse=False
    )

    topn  = zip(coefs[:n], coefs[:-(n+1):-1])

    # Create the output string to return
    output = []

    # If text, add the predicted value to the output.
    if text is not None:
        output.append("\"{}\"".format(text))
        output.append("Classified as: {}".format(model.predict([text])))
        output.append("")

    # Create two columns with most negative and most positive features.
    for (cp, fnp), (cn, fnn) in topn:
        output.append(
            "{:0.4f}{: >15}    {:0.4f}{: >15}".format(cp, fnp, cn, fnn)
        )

    return "\n".join(output)

# %%
get_company_names(list(cleaned_df["company"])[1])
# list(cleaned_df["company"])[1]
# Out:
# ['basf']

# %%
# get_company_names(list(cleaned_df["company"])[10])
# cleaned_df['lemmatized'] = cleaned_df.apply(lambda row: " ".join(tokenize(row['text'], get_company_names(row["company"]))), axis=1)

# %%
# list(cleaned_df["lemmatized"])[0]
# cleaned_df["sentiment"].unique()

# %%
X = cleaned_df["text"]
y = cleaned_df["sentiment"]
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42,
                                                    stratify=y)
model, secs = build_and_evaluate(X,y)
print(show_most_informative_features(model))
# Out:
# Building for evaluation
# /Users/bmarchenko/projects/prj-nlp/env/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# Evaluation model fit in 21.489 seconds
# Classification Report:
#
#                    precision    recall  f1-score   support
#
#          Negative       0.75      0.50      0.60        18
#           Neutral       0.20      0.25      0.22         4
#          Positive       0.67      0.87      0.75        23
# Strongly Negative       0.00      0.00      0.00         1
# Strongly Positive       0.00      0.00      0.00         3
#
#       avg / total       0.60      0.61      0.59        49
#
# Building complete model and saving ...
# Complete model fit in 24.301 seconds
# -3.4183            cut    4.2006           coal
# -2.8444             ”.    3.5445           file
# -2.8210            use    3.2368      fiduciary
# -2.8201           well    3.0694            sea
# -2.8161         ruling    3.0612        company
# -2.7291       emission    2.8979        general
# -2.7215          today    2.8921          shale
# -2.6423       business    2.8772       refinery
# -2.6237         reduce    2.7031       ministry
# -2.5623            day    2.6999        exclude
# -2.5566         energy    2.6172          blame
# -2.5434          power    2.5623       attorney
# -2.5232         global    2.5386         report
# -2.2863            ”..    2.5355          study
# -2.2104        vehicle    2.4428          legal
# -2.1825       electric    2.4061         diesel
# -2.0667              –    2.3145         review
# -2.0593       drilling    2.2864           info
# -2.0432              v    2.2830        promise
# -2.0029          solar    2.1963        bailout
# /Users/bmarchenko/projects/prj-nlp/env/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
X = cleaned_df["text"]
y = cleaned_df["simple_sentiment"]
# test_size = 0.2
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42,
#                                                     stratify=y)
model, secs = build_and_evaluate(X,y, outpath="model.pickle")
print(show_most_informative_features(model))
# Out:
# Building for evaluation
# /Users/bmarchenko/projects/prj-nlp/env/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# Evaluation model fit in 19.489 seconds
# Classification Report:
#
#              precision    recall  f1-score   support
#
#           0       0.85      0.69      0.76        16
#           1       0.76      0.96      0.85        26
#           2       0.33      0.14      0.20         7
#
# avg / total       0.73      0.76      0.73        49
#
# Building complete model and saving ...
# Complete model fit in 23.796 seconds
# Model written out to model.pickle
# -3.0646       electric    4.8334            oil
# -2.9960         energy    4.0591       fracking
# -2.8516       business    4.0484           coal
# -2.7830          court    3.5703       sanction
# -2.7705            use    3.4225          shale
# -2.5381        vehicle    3.3215        company
# -2.5043          power    2.7926          tonne
# -2.4668        percent    2.7369           file
# -2.4271          issue    2.6320      fiduciary
# -2.2902      renewable    2.6318         report
# -2.2831         global    2.5883        scandal
# -2.2749         ruling    2.5854          legal
# -2.2169         reduce    2.4886        general
# -2.2126          water    2.3988           case
# -2.1747          solar    2.3968       refinery
# -2.1344           cell    2.3858        plastic
# -2.0564              v    2.3806           fuel
# -2.0375           city    2.3738        exclude
# -2.0240          today    2.3637       scottish
# -2.0132           tree    2.3084        bailout
# /Users/bmarchenko/projects/prj-nlp/env/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %% [markdown]
# # Okay, let's estimate 50 companies

# %%
import pickle
with open("model.pickle", "rb") as fl:
    model = pickle.load(fl)
df = pd.read_csv("../1-Data/3-annotation/compiled_output.csv")
df.columns
df['text'] = df.apply(lambda row: "{} {}".format(row['title'], clean_text(str(row['content']))), axis=1)
df.drop(df[df.text.str.len() < 150].index, inplace=True)

# %%
len(df)
# Out:
# 3673

# %%
companies = df.groupby("company", as_index=False)
rows_list = []
for num, cp in enumerate(list(companies.groups.keys())):
    neg_url = ''
    pos_url = ''
    cp_df = df.loc[df['company'] == cp]
#     cp_df['lemmatized'] = cp_df.apply(lambda row: " ".join(tokenize(row['text'], get_company_names(row[""]))), axis=1)
    urls = list(cp_df['url'])
#     cp_df['text'] = cp_df.apply(lambda row: "{} {}".format(row[''], clean_text(str(row['content']))), axis=1)
    
    res = model.predict(cp_df['text'])
    counter = Counter(res)
    probs = model.predict_proba(cp_df['text'])
    
    negs, pos, neut = zip(*probs)
    neg_url = urls[negs.index(max(negs))]
    pos_url = urls[pos.index(max(pos))]

    rows_list.append({"company": cp, "pos_c":Counter(res)[1], "neg_c": Counter(res)[0], 'pos_p': sum(pos), 'neg_p': sum(negs), 'neg_url': f"<a href='{neg_url}' target='_blank'>Clickme</a>", 'pos_url': f"<a href='{pos_url}' target='_blank'>Clickme</a>"})#, "neg_url": neg_url,"pos_url": pos_url })
    print(f"{cp}: p: {Counter(res)[1]}, n: {Counter(res)[0]},  'pos_p': {sum(pos)}, 'neg_p': {sum(negs)}, neg_url: {neg_url},  pos_url: {pos_url},")
    
final_df =  pd.DataFrame(rows_list)
# Out:
# ABB: p: 54, n: 0,  'pos_p': 46.17268510173781, 'neg_p': 2.8735556377522933, neg_url: https://www.theguardian.com/travel/2012/may/13/st-abbs-scottish-borders-walk,  pos_url: http://novabus.com/2017/02/09/abb-nova-bus-announce-collaboration-electric-transportation/,
# AMD (Advanced Micro Devices): p: 57, n: 0,  'pos_p': 44.48950614639514, 'neg_p': 7.481047660856088, neg_url: https://www.thenational.ae/business/markets/mubadala-investment-sells-shares-in-amd-1.616794,  pos_url: https://obamawhitehouse.archives.gov/the-press-office/2015/11/30/white-house-announces-additional-commitments-american-business-act,
# Agnico-Eagle Mines Ltd.: p: 31, n: 8,  'pos_p': 22.068686532675862, 'neg_p': 11.644857206665176, neg_url: https://www.elementascience.org/articles/10.1525/elementa.281/,  pos_url: https://www.agnicoeagle.com/English/sustainability/standards/default.aspx,
# Amazon.com Inc.: p: 49, n: 1,  'pos_p': 38.271009333957856, 'neg_p': 7.25637231508499, neg_url: https://www.investopedia.com/news/amazons-annual-shareholder-meeting-what-expect-amzn/,  pos_url: https://www.scientificamerican.com/article/amazon-and-google-change-places-on-going-green/,
# Apple Inc: p: 59, n: 4,  'pos_p': 51.41367026392888, 'neg_p': 7.734131156022258, neg_url: https://insideclimatenews.org/news/07032018/shareholder-resolutions-climate-change-2-degrees-methane-lobbying-trump-administration,  pos_url: https://www.theverge.com/2018/4/9/17216656/apple-renewable-energy-worldwide-climate-change,
# Arcelor SA: p: 39, n: 9,  'pos_p': 31.753390376180324, 'neg_p': 11.020026304660478, neg_url: https://bankwatch.org/project/steel-giant-arcelormittal,  pos_url: https://www.wemeanbusinesscoalition.org/companies/,
# ArcelorMittal: p: 28, n: 8,  'pos_p': 22.654192267378093, 'neg_p': 9.200724917806092, neg_url: http://wesa.fm/post/coke-plant-agrees-15-million-penalty-air-pollution-western-pa-community,  pos_url: https://www.solvay.com/en/company/sustainability/Actions-for-climate/cop/COP22/index.html,
# AuFeminin.com: p: 56, n: 6,  'pos_p': 40.38525139501922, 'neg_p': 12.659964050169147, neg_url: http://www.takepart.com/flashcards/what-is-climate-change/index.html,  pos_url: http://www.nexans.com/eservice/Corporate-en/navigatepub_344497_-35924/Nexans_reaffirms_its_commitment_to_sustainable_mob.html,
# BASF AG: p: 114, n: 13,  'pos_p': 92.87585482374018, 'neg_p': 22.239211575797906, neg_url: https://insideclimatenews.org/news/09012018/exxon-california-coastal-cities-climate-change-damages-lawsuit-texas-court,  pos_url: http://www.accountability.org/cr-leaders-dirk-voeste-vice-president-sustainability-strategy-basf/,
# BMW: p: 104, n: 6,  'pos_p': 92.56267414642367, 'neg_p': 15.653067368472113, neg_url: https://www.cleanenergywire.org/news/why-german-diesel-summit-matters-climate-and-energy-policy,  pos_url: http://www.motorcycle-usa.com/2015/12/article/american-honda-bmw-group-sign-climate-pledge/,
# BP plc: p: 10, n: 27,  'pos_p': 11.082895690960495, 'neg_p': 22.75661705234363, neg_url: http://priceofoil.org/2017/09/22/san-francisco-oakland-sue-big-oil-over-climate-change/,  pos_url: http://www.climateactionprogramme.org/news/bp-to-cap-emissions-in-first-step-towards-fighting-climate-change,
# Bayer AG: p: 40, n: 6,  'pos_p': 31.212986184432147, 'neg_p': 8.883989265239535, neg_url: https://www.theguardian.com/world/2010/oct/24/tea-party-climate-change-deniers,  pos_url: http://www.climateactionprogramme.org/climate-leader-interviews/interview-with-ursula-mathar-vp-bmw-group,
# Bridgestone Corp.: p: 63, n: 1,  'pos_p': 52.740728873452056, 'neg_p': 7.121200540020563, neg_url: https://www.cbsnews.com/news/firestone-tire-settles-with-ford/,  pos_url: https://europe.solveclimatechange.com/speakers/,
# Bunge: p: 50, n: 11,  'pos_p': 38.82345600359689, 'neg_p': 15.08761472560552, neg_url: https://www.economist.com/news/special-report/21710632-oil-companies-need-heed-investors-concerns-how-deal-worries-about-stranded,  pos_url: https://hbr.org/2016/10/the-comprehensive-business-case-for-sustainability,
# Cargill Inc: p: 31, n: 7,  'pos_p': 28.010540781380694, 'neg_p': 8.693000878487313, neg_url: https://www.theguardian.com/sustainable-business/2015/dec/07/food-climate-footprint-cargill-tyson-yara-netherlands,  pos_url: https://www.nrdc.org/experts/david-b-goldstein/businesses-show-way-fight-against-climate-change-embracing-energy-standard,
# Chevron Corp.: p: 16, n: 98,  'pos_p': 26.09355324274798, 'neg_p': 82.89420548815775, neg_url: https://www.independent.co.uk/environment/chevron-oil-warn-climate-change-lawsuits-drilling-greenhouse-emissions-economically-infeasible-a7609411.html,  pos_url: https://www.ft.com/content/b32f9d10-3984-11e7-821a-6027b8a20f23,
# Continental AG: p: 55, n: 5,  'pos_p': 45.9867927421087, 'neg_p': 14.997640282832682, neg_url: https://www.smithsonianmag.com/science-nature/barrow-alaska-ground-zero-for-climate-change-7553696/,  pos_url: http://report.conti-online.com/2017/en/report/corporate-profile/environment.html,
# Daimler AG: p: 105, n: 14,  'pos_p': 91.73877243813178, 'neg_p': 20.049739796096684, neg_url: https://gizmodo.com/mercedes-benz-owner-daimler-ag-may-have-also-rigged-emi-1823142545,  pos_url: http://www.dw.com/en/how-eco-friendly-are-electric-cars/a-19441437,
# Dow Chemical: p: 43, n: 17,  'pos_p': 37.98727786318495, 'neg_p': 16.972087305492757, neg_url: https://www.vanityfair.com/news/2017/04/dow-chemical-endangered-species,  pos_url: https://www.hpe.com/us/en/insights/articles/climate-change-and-big-business-action-time-1708.html,
# Duke Energy: p: 36, n: 11,  'pos_p': 30.220846897766457, 'neg_p': 12.811294991957991, neg_url: https://www.utilitydive.com/news/report-duke-energy-to-release-climate-report-under-investor-pressure/518827/,  pos_url: https://globalwarmingisreal.com/2017/08/30/duke-energy-florida-clean-power/,
# EDS Corp.: p: 34, n: 4,  'pos_p': 24.896626742861844, 'neg_p': 9.095566657423259, neg_url: https://www.nytimes.com/2017/08/22/opinion/exxon-climate-change-.html,  pos_url: https://jcsr.springeropen.com/articles/10.1186/s40991-016-0002-8,
# Exxon Mobil Corp.: p: 16, n: 35,  'pos_p': 17.775663682161998, 'neg_p': 31.61820067871744, neg_url: https://www.corp-research.org/exxonmobil,  pos_url: http://thehill.com/policy/energy-environment/364435-exxon-to-disclose-climate-change-risks,
# Ford Motor Co.: p: 102, n: 15,  'pos_p': 88.13994820770426, 'neg_p': 22.151543324519665, neg_url: https://www.treehugger.com/corporate-responsibility/75-companies-which-backed-global-climate-coalition-lies-about-global-warming.html,  pos_url: https://www.mprnews.org/story/2018/01/18/climate-change-business-models,
# GazProm: p: 27, n: 38,  'pos_p': 26.92643806886383, 'neg_p': 33.443484339764126, neg_url: http://www.greenpeace.org/archive-international/en/news/Blogs/makingwaves/10-reasons-to-take-action-to-stop-gazproms-pr/blog/46766/,  pos_url: https://www.quotemyenergy.co.uk/gazprom/,
# General Motors Corp.: p: 117, n: 17,  'pos_p': 102.91219882366522, 'neg_p': 23.145054408729607, neg_url: https://www.treehugger.com/corporate-responsibility/75-companies-which-backed-global-climate-coalition-lies-about-global-warming.html,  pos_url: http://www.climateweeknyc.org/climate-group-launches-pioneering-global-ev-campaign-climate-week-nyc,
# Georgia Pacific: p: 54, n: 20,  'pos_p': 43.12385214295445, 'neg_p': 22.75866575972579, neg_url: https://www.greenpeace.org/usa/global-warming/climate-deniers/koch-industries/koch-industries-pollution/,  pos_url: http://www.solarfeeds.com/10-ways-georgia-pacific-keeps-it-green/,
# Glencore International AG: p: 18, n: 15,  'pos_p': 15.935413359235202, 'neg_p': 13.330376558462065, neg_url: https://www.apg.nl/en/vvb/dialogen-met-bedrijven-en-beleidmakers,  pos_url: https://www.ft.com/content/558c12a6-20c2-11e5-ab0f-6bb9974f25d0,
# Goodyear Tire & Rubber Co: p: 47, n: 5,  'pos_p': 39.290732777726845, 'neg_p': 8.234946947601442, neg_url: https://www.treehugger.com/corporate-responsibility/75-companies-which-backed-global-climate-coalition-lies-about-global-warming.html,  pos_url: http://www.sustainablebrands.com/news_and_views/waste_not/sustainable_brands/goodyear_turning_rice_husk_waste_fuel-efficient_tire_tre,
# IBM: p: 61, n: 0,  'pos_p': 52.603121893538436, 'neg_p': 2.993388513280308, neg_url: https://www.researchgate.net/publication/221654446_Spatial-temporal_causal_modeling_for_climate_change_attribution,  pos_url: https://www.mnn.com/money/sustainable-business-practices/stories/ibm-and-the-environment,
# Ineos: p: 8, n: 41,  'pos_p': 8.412232353803839, 'neg_p': 38.137710628782415, neg_url: http://powerbase.info/index.php/Ineos,  pos_url: https://friendsoftheearth.uk/climate-change/rejection-ineos-test-drill-application-south-yorkshire-welcomed,
# International Paper Corp.: p: 30, n: 10,  'pos_p': 25.337729680895617, 'neg_p': 11.735877558218363, neg_url: https://www.independent.co.uk/environment/exxonmobil-climate-change-oil-gas-fossil-fuels-global-warming-harvard-a7908541.html,  pos_url: https://www.softbank.jp/en/corp/csr/future/instance_04/contents_02/,
# Johnson & Johnson: p: 68, n: 4,  'pos_p': 48.78110216928309, 'neg_p': 15.505550122544319, neg_url: http://www.politifact.com/wisconsin/statements/2016/aug/12/ron-johnson/no-climate-warming-quite-few-years-gop-sen-ron-joh/,  pos_url: http://healthforhumanityreport.jnj.com/climate-and-energy,
# Kimberly-Clark Corp.: p: 57, n: 2,  'pos_p': 46.97649202330911, 'neg_p': 7.4531018675779, neg_url: https://insideclimatenews.org/news/04102017/greenpeace-rico-racketeering-lawsuit-environmental-activism-resolute-dakota-access-,  pos_url: https://www.bloomberg.org/press/releases/eighteen-u-s-businesses-cities-honored-climate-leadership-awards/,
# Michelin: p: 60, n: 1,  'pos_p': 48.18219532268601, 'neg_p': 7.633132794182881, neg_url: http://www.businessclimatesummit.com/london-2016/bcs-2016-speakers/,  pos_url: https://news.un.org/en/story/2014/09/478242-commitment-sustainable-transport-mobilized-un-climate-summit,
# Microsoft Corp.: p: 54, n: 2,  'pos_p': 47.23819866207839, 'neg_p': 4.484925067179782, neg_url: https://www.huffingtonpost.com/entry/ceos-bashing-paris-donate-to-climate-deniers_us_5937071de4b0aba888b9724b,  pos_url: https://www.epa.gov/climateleadership/2016-climate-leadership-award-winners,
# Motorola Inc.: p: 9, n: 1,  'pos_p': 7.115162033289631, 'neg_p': 1.2109730571112685, neg_url: http://www.mvalaw.com/practices-76.html,  pos_url: https://carbonfund.org/2011/09/20/motorola-unveils-worlds-first-mobile-phone-made-using-recycled-water-bottle-plastics-3/,
# Nestle SA: p: 33, n: 4,  'pos_p': 26.573510168343635, 'neg_p': 6.703498355525092, neg_url: https://www.ran.org/conflict_palm_oil,  pos_url: https://www.ferrero.com/group-news/,
# PepsiCo Inc.: p: 50, n: 7,  'pos_p': 43.78967732903712, 'neg_p': 9.604396341278074, neg_url: https://www.huffingtonpost.com/entry/companies-climate-change-donations_us_57cec288e4b0a22de096dab5,  pos_url: http://www.sustainablebrands.com/news_and_views/collaboration/sustainable_brands/l%E2%80%99or%C3%A9al_pepsico_strike_new_partnerships_push_forward,
# Petro China: p: 59, n: 32,  'pos_p': 47.35835326188942, 'neg_p': 32.756971391647774, neg_url: https://theferret.scot/scottish-ministers-fracking-firm-ineos/,  pos_url: https://www.energeticcity.ca/2018/01/horgan-staff-not-misled-lng/,
# Petrobras: p: 58, n: 47,  'pos_p': 51.08584787366168, 'neg_p': 45.820667186508864, neg_url: http://www.desmog.co.uk/2017/02/13/UK-Government-Last-Year-Gave-427-Million-to-Support-Fossil-Fuel-Projects-Abroad,  pos_url: http://www.zeroco2.no/projects/countries/brazil,
# Procter & Gamble, Co.: p: 58, n: 7,  'pos_p': 49.17777459608026, 'neg_p': 12.0422866891856, neg_url: https://changingtimes.media/2014/02/26/greenpeace-urges-procter-gamble-to-clean-up-its-palm-oil-supply-chain/,  pos_url: http://www.sustainablebrands.com/news_and_views/brand_innovation/hannah_furlong/pg_promises_15_billion_liters_clean_water_30_fewer_em,
# RosNeft: p: 15, n: 84,  'pos_p': 22.334451070351868, 'neg_p': 67.90755644654082, neg_url: http://priceofoil.org/2018/01/15/bp-accused-of-side-stepping-russian-sanctions/,  pos_url: http://news.exxonmobil.com/press-release/rosneft-and-exxonmobil-expand-strategic-cooperation,
# Royal Dutch Shell PLC: p: 47, n: 66,  'pos_p': 45.74000904131214, 'neg_p': 59.8512250738236, neg_url: https://www.insurancejournal.com/news/west/2017/09/21/465038.htm,  pos_url: https://www.chron.com/business/energy/article/Shell-CEO-Climate-change-is-our-biggest-issue-12735308.php,
# Samsung Electronics Co., Ltd.: p: 44, n: 3,  'pos_p': 33.713287981536745, 'neg_p': 8.775669603238835, neg_url: https://www.apg.nl/en/vvb/dialogen-met-bedrijven-en-beleidmakers,  pos_url: https://www.prworx.co.za/press,
# Sony Corp.: p: 44, n: 2,  'pos_p': 34.92655361680028, 'neg_p': 6.380222355042842, neg_url: https://www.usatoday.com/story/money/2017/06/02/exxon-mobil-rex-tillerson-eric-schneiderman-climate-change/102418492/,  pos_url: http://www.macleans.ca/canada-top-50-socially-responsible-corporations-2013/,
# Stora Enso Oyj: p: 36, n: 2,  'pos_p': 28.402302932210194, 'neg_p': 6.723012905057281, neg_url: http://www.maankohoumapuisto.fi/eng,  pos_url: http://www.fibsry.fi/fi/english/sustainability/new-business-from-sdgs,
# Sumitomo Rubber Industries: p: 93, n: 5,  'pos_p': 73.0671697531141, 'neg_p': 16.16691166087452, neg_url: http://www.sciencemag.org/news/2016/08/just-90-companies-are-blame-most-climate-change-carbon-accountant-says,  pos_url: https://www.wbcsd.org/Sector-Projects/Tire-Industry-Project/News/News/Tire-industry-engaged-in-sustainable-development-and-CO2-reduction,
# ThyssenKrupp Stahl: p: 30, n: 2,  'pos_p': 22.360724535005687, 'neg_p': 5.365088396941713, neg_url: http://stop-mad-mining.org/downloads/,  pos_url: https://wikivisually.com/wiki/Budd_Company,
# Toshiba Corp.: p: 43, n: 7,  'pos_p': 33.25245925498097, 'neg_p': 10.809979749323773, neg_url: http://fortune.com/2017/01/12/exxon-mobil-massachusetts-climate-change/,  pos_url: https://www.dsm.com/corporate/media/informationcenter-pub/2015/04/2015-04-17-open-letter-from-global-ceos-to-world-leaders-urging-concrete-climate-action.html,
# Total SA: p: 50, n: 11,  'pos_p': 37.48565490246789, 'neg_p': 15.779898619100974, neg_url: http://www.climatechangenews.com/2014/01/13/what-do-we-know-about-french-oil-major-total/,  pos_url: http://sdt.unwto.org/content/faq-climate-change-and-tourism,
# Toyota Motor Corp.: p: 132, n: 6,  'pos_p': 118.50722466568934, 'neg_p': 13.231242265160276, neg_url: https://www.reuters.com/article/us-california-autos/calif-suit-on-car-greenhouse-gases-dismissed-idUSN1736580020070918,  pos_url: https://blogs.thomsonreuters.com/answerson/toyotas-vision-climate-sustainability/,
# Volkswagen AG: p: 38, n: 9,  'pos_p': 31.972743242763336, 'neg_p': 12.41593984456156, neg_url: https://www.theguardian.com/business/2015/sep/22/vw-scandal-caused-nearly-1m-tonnes-of-extra-pollution-analysis-shows,  pos_url: http://media.daimler.com/marsMediaSite/en/instance/ko/Environment.xhtml?oid=9265793,
# Weyerhaeuser Co.: p: 48, n: 5,  'pos_p': 39.44066267216349, 'neg_p': 10.2708134545816, neg_url: https://www.reuters.com/article/us-usa-court-frog/u-s-top-court-takes-up-property-rights-case-involving-endangered-frog-idUSKBN1FB1YO,  pos_url: http://www.gogreenconference.net/advisory_board/,

# %%
categories = {"Food": ["Cargill Inc", "Nestle SA", "Procter & Gamble, Co.", "PepsiCo Inc.", "Bunge"],
            "Chemicals": ["BASF AG", "Johnson & Johnson", "Bayer AG", "Ineos", "Dow Chemical"],
            "Electronics": ["Samsung Electronics Co., Ltd.", "Sony Corp.", "AMD (Advanced Micro Devices)", "Toshiba Corp.", "Motorola Inc."],
            "Metals & mining": ["Glencore International AG", "ArcelorMittal", "Agnico-Eagle Mines Ltd.", "ThyssenKrupp Stahl", "Arcelor SA"],
            "Tires": ["Michelin", "Bridgestone Corp.", "Continental AG", "Goodyear Tire & Rubber Co", "Sumitomo Rubber Industries"],
            "Energy & water": ["GazProm", "Duke Energy", "Petrobras", "Petro China", "RosNeft", "BP plc", "Exxon Mobil Corp.", "Total SA", 'Royal Dutch Shell PLC', "Chevron Corp."],
            "Automotive & transport": ["General Motors Corp.", "BMW", "ABB", "Daimler AG", "Ford Motor Co.", "Toyota Motor Corp.", "Volkswagen AG"],
            "Wood & paper products": ["International Paper Corp.", "Georgia Pacific", "Weyerhaeuser Co.", "Stora Enso Oyj", "Kimberly-Clark Corp."],
            "Computer services & software": ["IBM", "Microsoft Corp.", "EDS Corp.", "AuFeminin.com", "Amazon.com Inc.", "Apple Inc"],
#             "Dirty Dozen": ["GazProm", "Petrobras", "RosNeft", "Petro China", "Duke Energy"]             
}
companies_dc = {}
for cat, companies in categories.items():
    for c in companies:
        companies_dc[c] = cat
cats = list(categories.keys())
final_df['category'] = final_df.apply(lambda row: companies_dc[row['company']], axis=1)
import matplotlib.pyplot as plt
from matplotlib import colors
def get_cmap(n, name='hsv'):
    '''Returns a function that maps each index in 0, 1, ..., n-1 to a distinct 
    RGB color; the keyword argument name must be a standard mpl colormap name.'''
    return plt.cm.get_cmap(name, n)
cmap = get_cmap(len(cats))
#http://www.climatechangenews.com/2015/05/21/the-dirty-dozen-the-fossil-fuel-industrys-polluting-league-table/
dirty_dozen = ["GazProm", "Petrobras", "RosNeft", "Petro China", "Glencore International AG", 'Royal Dutch Shell PLC', "Exxon Mobil Corp.", "BP plc", "Chevron Corp."]

def highlight_categories(row):
    return [f'background-color: {colors.rgb2hex(cmap(cats.index(row["category"])))}' for i in row]

def highlight_dirty_dozen(row):
    if row["company"] in dirty_dozen:
        return ['background-color: red' for i in row]
    else:
        return ["" for i in row]

# %%
# lemmatizer = WordNetLemmatizer()
# stopwords = set(sw.words('english'))
# def lemmatize(token, tag):
#     """
#     Converts the Penn Treebank tag to a WordNet POS tag, then uses that
#     tag to perform much more accurate WordNet lemmatization.
#     """
#     tag = {
#         'N': wn.NOUN,
#         'V': wn.VERB,
#         'R': wn.ADV,
#         'J': wn.ADJ
#     }.get(tag[0], wn.NOUN)

#     return lemmatizer.lemmatize(token, tag)

# def tokenize(document, company_names):
#     doc_tokens = []

#     for sent in sent_tokenize(document):
#         company_in_sent = False
#         sent_tokens = []
#         # Break the sentence into part of speech tagged tokens
#         for token, tag in pos_tag(wordpunct_tokenize(sent)):
#             # Apply preprocessing to the token
#             token = token.lower()
#             token = token.strip()
#             token = token.strip('_')
#             token = token.strip('*')

#             # If punctuation or stopword, ignore token and continue
# #             import ipdb; ipdb.set_trace()
#             if token in stopwords or all(char in set(string.punctuation) for char in token):
#                 continue
#             if tag == "NNP":
#                 continue
#             # Lemmatize the token and yield
#             lemma = lemmatize(token, tag)
#             if lemma in company_names:
#                 company_in_sent = True
#             sent_tokens.append(lemma)
#         if company_in_sent:
            
#             doc_tokens.extend(sent_tokens)
# #                 break
# #     if len(doc_tokens) == 0:
# #         print(document)
# #         print(company_names)
# #         import ipdb; ipdb.set_trace()
# #     print(company_names[0], len(doc_tokens))
#     return doc_tokens

# %% [markdown]
# ### Order by absolute number of negatives/positives.  Highlight sectors

# %%
final_df['mark'] = final_df['neg_c']/final_df['pos_c']
final_df = final_df.sort_values(['mark'], ascending=[0])
# final_df['pos_url'] = final_df.apply(lambda row: f"<a href='{row['pos_url']}'>{row['pos_url']}</a>", axis=1)

final_df.style.apply(highlight_categories, axis=1)
# HTML(final_df.to_html(escape=False))
# final_df.style.apply(highlight_dirty_dozen, axis=1)
# Out:
# <style  type="text/css" >
#     #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row0_col0 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row0_col1 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row0_col2 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row0_col3 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row0_col4 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row0_col5 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row0_col6 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row0_col7 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row0_col8 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row1_col0 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row1_col1 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row1_col2 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row1_col3 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row1_col4 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row1_col5 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row1_col6 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row1_col7 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row1_col8 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row2_col0 {
#             background-color:  #ffbc00;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row2_col1 {
#             background-color:  #ffbc00;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row2_col2 {
#             background-color:  #ffbc00;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row2_col3 {
#             background-color:  #ffbc00;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row2_col4 {
#             background-color:  #ffbc00;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row2_col5 {
#             background-color:  #ffbc00;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row2_col6 {
#             background-color:  #ffbc00;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row2_col7 {
#             background-color:  #ffbc00;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row2_col8 {
#             background-color:  #ffbc00;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row3_col0 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row3_col1 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row3_col2 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row3_col3 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row3_col4 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row3_col5 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row3_col6 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row3_col7 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row3_col8 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row4_col0 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row4_col1 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row4_col2 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row4_col3 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row4_col4 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row4_col5 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row4_col6 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row4_col7 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row4_col8 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row5_col0 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row5_col1 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row5_col2 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row5_col3 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row5_col4 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row5_col5 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row5_col6 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row5_col7 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row5_col8 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row6_col0 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row6_col1 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row6_col2 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row6_col3 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row6_col4 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row6_col5 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row6_col6 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row6_col7 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row6_col8 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row7_col0 {
#             background-color:  #00ff37;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row7_col1 {
#             background-color:  #00ff37;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row7_col2 {
#             background-color:  #00ff37;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row7_col3 {
#             background-color:  #00ff37;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row7_col4 {
#             background-color:  #00ff37;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row7_col5 {
#             background-color:  #00ff37;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row7_col6 {
#             background-color:  #00ff37;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row7_col7 {
#             background-color:  #00ff37;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row7_col8 {
#             background-color:  #00ff37;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row8_col0 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row8_col1 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row8_col2 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row8_col3 {
#             background-color:  #004fff;
#         }    #T_9eccbcec_6294_11e8_9ba1_b8e8560d5912row8_col4 {
#             bac

# %% [markdown]
# # Naive validation: highlight Dirty Dozen

# %%
final_df.style.apply(highlight_dirty_dozen, axis=1)
# Out:
# <style  type="text/css" >
#     #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row0_col0 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row0_col1 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row0_col2 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row0_col3 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row0_col4 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row0_col5 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row0_col6 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row0_col7 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row0_col8 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row1_col0 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row1_col1 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row1_col2 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row1_col3 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row1_col4 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row1_col5 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row1_col6 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row1_col7 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row1_col8 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row3_col0 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row3_col1 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row3_col2 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row3_col3 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row3_col4 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row3_col5 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row3_col6 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row3_col7 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row3_col8 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row4_col0 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row4_col1 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row4_col2 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row4_col3 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row4_col4 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row4_col5 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row4_col6 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row4_col7 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row4_col8 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row5_col0 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row5_col1 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row5_col2 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row5_col3 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row5_col4 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row5_col5 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row5_col6 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row5_col7 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row5_col8 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row6_col0 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row6_col1 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row6_col2 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row6_col3 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row6_col4 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row6_col5 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row6_col6 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row6_col7 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row6_col8 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row7_col0 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row7_col1 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row7_col2 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row7_col3 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row7_col4 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row7_col5 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row7_col6 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row7_col7 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row7_col8 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row8_col0 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row8_col1 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row8_col2 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row8_col3 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row8_col4 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row8_col5 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row8_col6 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row8_col7 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row8_col8 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row9_col0 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row9_col1 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row9_col2 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row9_col3 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row9_col4 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row9_col5 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row9_col6 {
#             background-color:  red;
#         }    #T_9ef76b2c_6294_11e8_b089_b8e8560d5912row9_col7 {
#             backgro

# %% [markdown]
# ### Order by sum of probabilities negatives/positives

# %%
# final_df['mark'] = final_df['neg_p']/final_df['pos_p']
# final_df = final_df.sort_values(['mark'], ascending=[0])
# final_df.style.apply(highlight_categories, axis=1)

# %% [markdown]
# ### Order by avg probability negatives/positives

# %%
# final_df['mark'] =  (final_df['pos_p']/final_df['pos_c'])- (final_df['neg_p']/final_df['neg_c'])
# final_df.sort_values(['mark'], ascending=[0])
# final_df.style.apply(highlight_categories, axis=1)

# %%
# print(f"length before: {len(df)}")
# df['title'] = df['']
# df['company'] = df['']
# df['text'] = df.apply(lambda row: "{} {}".format(row[''], clean_text(str(row['content']))), axis=1)

# for num, row in df.iterrows():
#     cc = find_company_confidence(row)
#     if cc == 0:

# %%
# df['company_confidence'] = df.apply(lambda row: find_company_confidence(row) ,axis=1)
# df = df[df['company_confidence'][0] != 0]
# print(f"length after: {len(df)}")

# %%
# df['company_confidence'] = df.apply(lambda row: row['company_confidence'][0] ,axis=1)

# %%
# df = df[df['company_confidence'] != 0]
# print(f"length after: {len(df)}")

# %%
# companies = df.groupby("", as_index=False)
# rows_list = []
# for num, cp in enumerate(list(companies.groups.keys())):
#     cp_df = df.loc[df[''] == cp]
#     res = model.predict(cp_df['text'])
#     rows_list.append({"company": cp, "pos":Counter(res)[1], "neg": Counter(res)[0], "mark": Counter(res)[0]/Counter(res)[1] })
#     print(f"{cp}: p: {Counter(res)[1]}, n: {Counter(res)[0]}, {round(Counter(res)[0]/Counter(res)[1],3)}")
    
# final_df =  pd.DataFrame(rows_list) 
# final_df.sort_values(['mark'], ascending=[0])

# %%
X = cleaned_df["text"]
y = cleaned_df["simple_sentiment"]
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42,
                                                    stratify=y)
print(f"Num. of train: {len(X_train)}, Num. of test: {len(X_test)}")
priors = y_train.value_counts(normalize=True).values
vectorizer = TfidfVectorizer(**tf_params)
train = vectorizer.fit_transform(X_train)
test = vectorizer.transform(X_test)
clf = MultinomialNB()
clf.fit(train.toarray(), y_train)
pred = clf.predict(test.toarray())
print(classification_report(y_test, pred, target_names=[0,1,2]))
